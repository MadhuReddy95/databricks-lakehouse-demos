-- %%
%sql
SHOW STORAGE CREDENTIALS

-- %%
use catalog retail

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS retail_ext_location
URL 'abfss://retail@<storage-account>.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL adls_credential)
COMMENT 'external location for retail'

-- %%
%sql
CREATE CATALOG IF NOT EXISTS retail
      MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/'
      COMMENT 'catalog for DLT demo'

-- %%
SHOW CATALOGS

-- %%
USE CATALOG retail

-- %%
CREATE SCHEMA IF NOT EXISTS landing
      MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/landing'
      COMMENT 'schema for raw data';

CREATE SCHEMA IF NOT EXISTS deltalake
      MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/deltalake'
      COMMENT 'schema for processed data';

-- %% [markdown]
-- CREATE SCHEMA IF NOT EXISTS bronze
--       MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/bronze'
--       COMMENT 'schema for processed data';
--
-- CREATE SCHEMA IF NOT EXISTS silver
--       MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/silver'
--       COMMENT 'schema for processed data';
--
-- CREATE SCHEMA IF NOT EXISTS gold
--       MANAGED LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/gold'
--       COMMENT 'schema for processed data';

-- %%
SHOW SCHEMAS

-- %%
USE CATALOG retail;
USE SCHEMA landing;

-- %% [markdown]
-- ### kEY WORDS BELOW:
-- - "EXTERNAL" VOLUME
-- - "LOCATION"

-- %%
CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
      LOCATION 'abfss://retail@<storage-account>.dfs.core.windows.net/landing/operational_data'
      COMMENT 'volume for operational data'
